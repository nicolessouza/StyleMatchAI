# %%
# !pip install sentence-transformers

# %%
import pandas as pd

# %% [markdown]
# ## Gerador de embeddings escolhido: CLIP (Contrastive Language-Image Pretraining)
#
# O modelo CLIP (Contrastive Language-Image Pretraining) foi o escolhido para gerar os embeddings dos produtos, pois ele é capaz de combinar tanto a imagem quanto a descrição textual de cada produto em um único espaço latente. É de nosso interesse que o embedding da imagem e o da descrição fiquem próximos, facilitando a comparação entre diferentes representações do mesmo produto.
#
# Fonte interessante: <https://medium.com/crayon-ai/search-engine-for-clothes-using-clip-2f13d14c6b68>

# %%
from sentence_transformers import SentenceTransformer, util
from PIL import Image, ImageFile
import requests
import torch

# We use the original clip-ViT-B-32 for encoding images
img_model = SentenceTransformer('clip-ViT-B-32')

# Our text embedding model is aligned to the img_model and maps 50+
# languages to the same vector space
text_model = SentenceTransformer('sentence-transformers/clip-ViT-B-32-multilingual-v1')
# Out:
# c:\Users\Cole\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# c:\Users\Cole\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# c:\Users\Cole\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# c:\Users\Cole\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Cole\.cache\huggingface\hub\models--sentence-transformers--clip-ViT-B-32-multilingual-v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.65k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/572 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/539M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/371 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.57M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.57M [00:00<?, ?B/s]

# %% [markdown]
# ### Gerando embeddings
#
# - passa por todas as imagens e gera o embedding
# - salva o resultado em um df, de colunas nome_arquivo, emb_0, emb_1 ...
# - salva o df em um arquivo parquet

# %%
# Puxando base para gerar embeddings
df = pd.read_parquet("datasets/base_animale_categorizada.parquet")

# %%
df.head()
# Out:
#                                            file_path       id_produto  \
# 0  animale_images_cropped/blazer/blazer_blazer-al...  03-04-0464-0030
# 1  animale_images_cropped/blazer/blazer_blazer-al...  03-04-0478-6048
# 2  animale_images_cropped/blazer/blazer_blazer-ci...  03-04-0460-0003
# 3  animale_images_cropped/blazer/blazer_blazer-ci...  03-04-0461-0005
# 4  animale_images_cropped/blazer/blazer_blazer-co...  03-04-0479-0024
#
#   grupo_produto                                          file_name  \
# 0        blazer  blazer_blazer-alfaiataria-est-onca-jacquard_be...
# 1        blazer  blazer_blazer-alongado-marrom-nozes-sem-lapela...
# 2        blazer  blazer_blazer-cinque-off-white_off-white_03-04...
# 3        blazer  blazer_blazer-cinque-preto_preto_03-04-0461-00...
# 4        blazer  blazer_blazer-com-transpasse-de-crepe-off-whit...
#
#                                                 link         PRODUTOS  \
# 0  https://animaleproductsimages.s3.us-east-1.ama...  03-04-0464-0030
# 1  https://animaleproductsimages.s3.us-east-1.ama...  03-04-0478-6048
# 2  https://animaleproductsimages.s3.us-east-1.ama...  03-04-0460-0003
# 3  https://animaleproductsimages.s3.us-east-1.ama...  03-04-0461-0005
# 4  https://animaleproductsimages.s3.us-east-1.ama...  03-04-0479-0024
#
#                                      CARACTERISTICAS LOCALIZACAO_ESTAMPA  \
# 0  {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRI...       ROUPA_INTEIRA
# 1  {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRI...                 N/A
# 2  {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRI...                 N/A
# 3  {COMPRIMENTO: MEDIO; MODELAGEM: AJUSTADA; COMP...                 N/A
# 4  {COMPRIMENTO: MEDIO; MODELAGEM: AJUSTADA; COMP...                 N/A
#
#   COR_PREDOMINANTE DECOTE_OU_GOLA  ... COMPRIMENTO_MANGA  ESTILO TIPO_MANGA  \
# 0             BEGE           None  ...          COMPRIDA  CASUAL    REGULAR
# 1             BEGE           None  ...          COMPRIDA  SOCIAL    REGULAR
# 2           BRANCO           None  ...          COMPRIDA  SOCIAL    REGULAR
# 3            PRETO           None  ...          COMPRIDA  SOCIAL    REGULAR
# 4           BRANCO           None  ...          COMPRIDA  SOCIAL    REGULAR
#
#   TIPO_CINTURA COMPRIMENTO MODELAGEM           ESTAMPA FENDA_PERNA  \
# 0         None       MEDIO  AJUSTADA  ANIMALPRINT_ONCA        None
# 1         None       MEDIO  AJUSTADA       SEM_ESTAMPA        None
# 2         None       MEDIO  AJUSTADA       SEM_ESTAMPA        None
# 3         None       MEDIO  AJUSTADA       SEM_ESTAMPA        None
# 4         None       MEDIO  AJUSTADA       SEM_ESTAMPA        None
#
#   MODELAGEM_SAIA TIPO_BARRA
# 0           None       None
# 1           None       None
# 2           None       None
# 3           None       None
# 4           None       None
#
# [5 rows x 23 columns]

# %%
from tqdm import tqdm

def get_img_embeddings(df, path_column, img_model):
  """
  Função que recebe um dataframe, a coluna que contém o caminho das imagens e o modelo de imagem
  Usa o modelo para conseguir os embeddings da imagem e salva no df
  """
  emb_columns = [f"emb_img_{i}" for i in range(512)]
  
  # Now we load and encode the images
  def load_image(url_or_path):
      if url_or_path.startswith("http://") or url_or_path.startswith("https://"):
          return Image.open(requests.get(url_or_path, stream=True).raw)
      else:
          return Image.open(url_or_path)

  file_names = df[path_column].values
  images = [load_image(img) for img in file_names]
  img_embeddings = img_model.encode(images)

  # Colocando os embeddings no df
  emb_dict = {}
  for i, emb in enumerate(img_embeddings):
    emb_id = df.iloc[i]["id_produto"]
    emb_dict[emb_id] = emb

  df_embs = pd.DataFrame(emb_dict).T

  df_embs.columns = emb_columns
  df_embs["id_produto"] = df_embs.index

  return df_embs.reset_index(drop=True)[["id_produto"] + emb_columns]

def get_text_embeddings(df, text_model):
  """
  Função que recebe um dataframe e o modelo de texto
  Usa o modelo para conseguir os embeddings da coluna desc_produto e salva no df
  """

  emb_columns = [f"emb_text_{i}" for i in range(512)]
  
  # Now we encode the text
  text_embeddings = text_model.encode(df["desc_produto"].values)

  # Colocando os embeddings no df
  emb_dict = {}
  for i, emb in enumerate(text_embeddings):
    emb_id = df.iloc[i]["id_produto"]
    emb_dict[emb_id] = emb

  df_embs = pd.DataFrame(emb_dict).T

  df_embs.columns = emb_columns

  df_embs["id_produto"] = df_embs.index

  return df_embs.reset_index(drop=True)[["id_produto"] + emb_columns]

# %%
df.loc[df['id_produto'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [file_path, id_produto, grupo_produto, file_name, link, PRODUTOS, CARACTERISTICAS, LOCALIZACAO_ESTAMPA, COR_PREDOMINANTE, DECOTE_OU_GOLA, COMPRIMENTO_SAIA, AMARRACAO, ZOOM_ESTAMPA, COMPRIMENTO_MANGA, ESTILO, TIPO_MANGA, TIPO_CINTURA, COMPRIMENTO, MODELAGEM, ESTAMPA, FENDA_PERNA, MODELAGEM_SAIA, TIPO_BARRA]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_img_embs = get_img_embeddings(df, "file_path", img_model)

# %%
df_img_embs.shape
# Out:
# (766, 513)

# %%
df_img_embs.to_parquet("datasets/img_embeddings.parquet")
df_img_embs.head(1)
# Out:
#         id_produto  emb_img_0  emb_img_1  emb_img_2  emb_img_3  emb_img_4  \
# 0  03-04-0464-0030   0.159315  -0.024293  -0.117268   0.017468  -0.192906
#
#    emb_img_5  emb_img_6  emb_img_7  emb_img_8  ...  emb_img_502  emb_img_503  \
# 0   0.137711  -0.402171  -0.144309   0.939456  ...    -0.028948    -0.075428
#
#    emb_img_504  emb_img_505  emb_img_506  emb_img_507  emb_img_508  \
# 0     0.560166    -0.266601    -0.213009     0.003456      0.25105
#
#    emb_img_509  emb_img_510  emb_img_511
# 0     0.798051    -0.282096     0.032521
#
# [1 rows x 513 columns]

# %% [markdown]
# ### Extraindo descrições dos produtos
# As imagens foram nomeadas de forma que contém o ID do produto e sua respectiva descrição. Vamos extrair essas descrições para gerar embeddings dos textos também.

# %%
pd.set_option('display.max_colwidth', None)

# %%
df['file_name'].sample(2)
# Out:
# 263    top-blusa_blusa-de-malha-com-decote-v-e-manga-longa-raglan_branco_52-13-5456-0001.jpg
# 213           camisa_camisa-de-tricoline-listrada-verde-cage_verde-gage_03-06-0340-09254.jpg
# Name: file_name, dtype: object

# %%
# Iterando nos filedf['file_name'] e pegando tudo após o primeiro -
df['desc_produto'] = df['file_name'].apply(lambda x: x.split("_")[1]).replace("-", " ", regex=True)

# %%
df.sample(5)
# Out:
#                                                                                                                                          file_path  \
# 499  animale_images_cropped/saia/saia_saia-de-georgette-longa-com-fenda-e-franjas-estampado_est-floral-geometrico-block-color_25-11-1220-09546.jpg
# 235                                       animale_images_cropped/blusa/top-blusa_bata-de-georgette-preta-com-manga-curta_preto_52-13-5421-0005.jpg
# 135                               animale_images_cropped/calca/calca_calca-jeans-boot-70-s-com-resina-transparente_jeans-claro_25-34-1773-0101.jpg
# 36                                  animale_images_cropped/calca/calca_calca-cenoura-detalhe-torcao-na-frente-azul_azul-print_25-34-1700-09246.jpg
# 542                                           animale_images_cropped/short/short_short-de-linho-bege-amendoado_bege-amendoado_25-05-4135-04343.jpg
#
#            id_produto grupo_produto  \
# 499  25-11-1220-09546          saia
# 235   52-13-5421-0005         blusa
# 135   25-34-1773-0101         calca
# 36   25-34-1700-09246         calca
# 542  25-05-4135-04343         short
#
#                                                                                                              file_name  \
# 499  saia_saia-de-georgette-longa-com-fenda-e-franjas-estampado_est-floral-geometrico-block-color_25-11-1220-09546.jpg
# 235                                        top-blusa_bata-de-georgette-preta-com-manga-curta_preto_52-13-5421-0005.jpg
# 135                                calca_calca-jeans-boot-70-s-com-resina-transparente_jeans-claro_25-34-1773-0101.jpg
# 36                                   calca_calca-cenoura-detalhe-torcao-na-frente-azul_azul-print_25-34-1700-09246.jpg
# 542                                            short_short-de-linho-bege-amendoado_bege-amendoado_25-05-4135-04343.jpg
#
#                                                                                                                                                                            link  \
# 499  https://animaleproductsimages.s3.us-east-1.amazonaws.com/saia_saia-de-georgette-longa-com-fenda-e-franjas-estampado_est-floral-geometrico-block-color_25-11-1220-09546.jpg
# 235                                        https://animaleproductsimages.s3.us-east-1.amazonaws.com/top-blusa_bata-de-georgette-preta-com-manga-curta_preto_52-13-5421-0005.jpg
# 135                                https://animaleproductsimages.s3.us-east-1.amazonaws.com/calca_calca-jeans-boot-70-s-com-resina-transparente_jeans-claro_25-34-1773-0101.jpg
# 36                                   https://animaleproductsimages.s3.us-east-1.amazonaws.com/calca_calca-cenoura-detalhe-torcao-na-frente-azul_azul-print_25-34-1700-09246.jpg
# 542                                            https://animaleproductsimages.s3.us-east-1.amazonaws.com/short_short-de-linho-bege-amendoado_bege-amendoado_25-05-4135-04343.jpg
#
#              PRODUTOS  \
# 499  25-11-1220-09546
# 235   52-13-5421-0005
# 135   25-34-1773-0101
# 36   25-34-1700-09246
# 542  25-05-4135-04343
#
#                                                                                                                                                                                                                              CARACTERISTICAS  \
# 499  {COMPRIMENTO: CALCANHAR; MODELAGEM: EVASÊ; TIPO_CINTURA: MEDIA; TIPO_BARRA: RETA; AMARRACAO: N/A; FENDA_PERNA: SIM; COR_PREDOMINANTE: BEGE; LOCALIZACAO_ESTAMPA: ROUPA_INTEIRA; ZOOM_ESTAMPA: MEDIO; ESTAMPA: FLORAL; ESTILO: FESTIVO;}
# 235    {COMPRIMENTO: CURTA;MODELAGEM: SOLTA;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: FLUTTER;DECOTE_OU_GOLA: REDONDA;AMARRACAO: N/A;COR_PREDOMINANTE: PRETO;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: CASUAL;}
# 135                {COMPRIMENTO: CALCANHAR;TIPO_CINTURA: ALTA;MODELAGEM: PANTALONA;TIPO_BARRA: RETA;AMARRACAO: N/A;FENDA_PERNA: N/A;COR_PREDOMINANTE: JEANS;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: CASUAL;}
# 36      {COMPRIMENTO: MEIO_CANELA;TIPO_CINTURA: MEDIA;MODELAGEM: SLIM;TIPO_BARRA: AJUSTADA;AMARRACAO: SIM_NA_FRENTE;FENDA_PERNA: N/A;COR_PREDOMINANTE: AZUL;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: CASUAL;}
# 542                                 {COMPRIMENTO: CURTO; MODELAGEM: SOLTA; TIPO_CINTURA: ALTA; TIPO_BARRA: RETA; AMARRACAO: N/A; COR_PREDOMINANTE: BEGE; LOCALIZACAO_ESTAMPA: N/A; ZOOM_ESTAMPA: N/A; ESTAMPA: SEM_ESTAMPA; ESTILO: CASUAL;}
#
#     LOCALIZACAO_ESTAMPA COR_PREDOMINANTE DECOTE_OU_GOLA  ...   ESTILO  \
# 499       ROUPA_INTEIRA             BEGE           None  ...  FESTIVO
# 235                 N/A            PRETO        REDONDA  ...   CASUAL
# 135                 N/A            JEANS           None  ...   CASUAL
# 36                  N/A             AZUL           None  ...   CASUAL
# 542                 N/A             BEGE           None  ...   CASUAL
#
#     TIPO_MANGA TIPO_CINTURA  COMPRIMENTO  MODELAGEM      ESTAMPA FENDA_PERNA  \
# 499       None        MEDIA    CALCANHAR      EVASÊ       FLORAL         SIM
# 235    FLUTTER         None        CURTA      SOLTA  SEM_ESTAMPA        None
# 135       None         ALTA    CALCANHAR  PANTALONA  SEM_ESTAMPA         N/A
# 36        None        MEDIA  MEIO_CANELA       SLIM  SEM_ESTAMPA         N/A
# 542       None         ALTA        CURTO      SOLTA  SEM_ESTAMPA        None
#
#     MODELAGEM_SAIA TIPO_BARRA  \
# 499           None       RETA
# 235           None       None
# 135           None       RETA
# 36            None   AJUSTADA
# 542           None       RETA
#
#                                               desc_produto
# 499  saia de georgette longa com fenda e franjas estampado
# 235                bata de georgette preta com manga curta
# 135          calca jeans boot 70 s com resina transparente
# 36             calca cenoura detalhe torcao na frente azul
# 542                          short de linho bege amendoado
#
# [5 rows x 24 columns]

# %%
# Extraindo embeddings de texto
df_text_embs = get_text_embeddings(df, text_model)

# %%
df_text_embs.sample(2)
# Out:
#            id_produto  emb_text_0  emb_text_1  emb_text_2  emb_text_3  \
# 727   07-20-6557-0003   -0.100979   -0.078410   -0.062100    0.164635
# 213  03-06-0340-09254   -0.089480    0.000263   -0.294809   -0.067149
#
#      emb_text_4  emb_text_5  emb_text_6  emb_text_7  emb_text_8  ...  \
# 727   -0.026903    0.061012    0.104670   -0.883950    0.090251  ...
# 213    0.127037   -0.084255   -0.094716   -0.616279   -0.221352  ...
#
#      emb_text_502  emb_text_503  emb_text_504  emb_text_505  emb_text_506  \
# 727     -0.054291      0.260104      0.415962     -0.170829      0.118398
# 213      0.257067     -0.027655      0.860039     -0.328919     -0.029834
#
#      emb_text_507  emb_text_508  emb_text_509  emb_text_510  emb_text_511
# 727     -0.019827      0.052236      0.110620      0.001344     -0.281924
# 213     -0.260095      0.027513      0.296024     -0.077862      0.398272
#
# [2 rows x 513 columns]

# %%
df_text_embs.to_parquet("datasets/text_embeddings.parquet")

# %% [markdown]
# ## Testando semelhança entre as descrições

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Extraímos os embeddings de imagem e texto dos respectivos dataframes
img_embeddings = df_img_embs.iloc[:, 1:].values  # Todas as colunas exceto 'id'
text_embeddings = df_text_embs.iloc[:, 1:].values  # Todas as colunas exceto 'id'

# Calculamos a similaridade de cosseno entre todos os pares de vetores de texto e imagem
# cosine_similarity calcula a similaridade entre cada vetor de um conjunto e cada vetor de outro conjunto
cos_sim = cosine_similarity(text_embeddings, img_embeddings)

# Para cada texto, encontramos a imagem mais similar com base na similaridade de cosseno
for i, text in enumerate(df_text_embs['id_produto']):  # Itera sobre os IDs dos textos
    scores = cos_sim[i]  # Similaridades do texto i com todas as imagens
    max_img_idx = np.argmax(scores)  # Índice da imagem com maior similaridade
    
    print("Texto ID:", text, "\nTexto:", df.iloc[i]['desc_produto'])
    print("Maior Similaridade:", scores[max_img_idx])
    print("Imagem ID:", df_img_embs.iloc[max_img_idx]["id_produto"], df.iloc[max_img_idx]['desc_produto'])
    print(" --------------------- \n")
# Out:
# Texto ID: 03-04-0464-0030
# Texto: blazer alfaiataria est onca jacquard
# Maior Similaridade: 0.24679223
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 03-04-0478-6048
# Texto: blazer alongado marrom nozes sem lapela
# Maior Similaridade: 0.2616407
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 03-04-0460-0003
# Texto: blazer cinque off white
# Maior Similaridade: 0.28952307
# Imagem ID: 03-04-0491-0003 blazer de crepe off white
#  ---------------------
#
# Texto ID: 03-04-0461-0005
# Texto: blazer cinque preto
# Maior Similaridade: 0.27307478
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 03-04-0479-0024
# Texto: blazer com transpasse de crepe off white
# Maior Similaridade: 0.29386935
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 03-04-0462-09256
# Texto: blazer cropped uno amarelo narciso
# Maior Similaridade: 0.2849918
# Imagem ID: 03-04-0462-09256 blazer cropped uno amarelo narciso
#  ---------------------
#
# Texto ID: 03-04-0447-0278
# Texto: blazer de algodao khaki
# Maior Similaridade: 0.27890792
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 03-01-1628-04346
# Texto: blazer de couro acinturado botoes organicos
# Maior Similaridade: 0.27713633
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 03-04-0431-09041
# Texto: blazer de crepe bege cropped
# Maior Similaridade: 0.2683753
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 03-04-0491-0003
# Texto: blazer de crepe off white
# Maior Similaridade: 0.29276836
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 03-04-0484-8259
# Texto: blazer de crepe vermelho fiery
# Maior Similaridade: 0.27366677
# Imagem ID: 03-04-0484-8259 blazer de crepe vermelho fiery
#  ---------------------
#
# Texto ID: 03-04-0465-0024
# Texto: blazer de linho oversized off white
# Maior Similaridade: 0.32655585
# Imagem ID: 25-34-1627-0003 calca de linho off white
#  ---------------------
#
# Texto ID: 03-04-0483-0005
# Texto: blazer de linho preto
# Maior Similaridade: 0.27497074
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 03-01-1620-09248
# Texto: blazer laranja aura detalhe botoes
# Maior Similaridade: 0.2916485
# Imagem ID: 25-34-1718-09634 calca de georgette pesado ampla estampada
#  ---------------------
#
# Texto ID: 03-01-1624-0005
# Texto: blazer sport
# Maior Similaridade: 0.24713689
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 03-04-0439-09040
# Texto: blazer transpassado mix la lilas nuvem
# Maior Similaridade: 0.26496115
# Imagem ID: 52-06-0644-09257 camiseta slim
#  ---------------------
#
# Texto ID: 03-04-0467-0800
# Texto: blazer uno bege madeira
# Maior Similaridade: 0.2407769
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 03-06-0331-09247
# Texto: colete bege gergelim
# Maior Similaridade: 0.23112015
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2029-09275
# Texto: calca alfaiataria bege curry
# Maior Similaridade: 0.2350797
# Imagem ID: 25-11-1209-09654 saia midi enviesada estampada
#  ---------------------
#
# Texto ID: 25-34-2037-09281
# Texto: calca alfaiataria linho marrom bordo
# Maior Similaridade: 0.2660825
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1636-5339
# Texto: calca alfaiataria reta verde exoutique c
# Maior Similaridade: 0.28577816
# Imagem ID: 25-34-1928-04113 calca de tricot maxi canelado
#  ---------------------
#
# Texto ID: 25-34-2036-09279
# Texto: calca alfaiataria riscas coral camelia
# Maior Similaridade: 0.25959522
# Imagem ID: 25-34-1638-09247 calca de algodao contraforma bege com elastico cintura
#  ---------------------
#
# Texto ID: 25-34-1744-01011
# Texto: calca amarelo papiro
# Maior Similaridade: 0.26944366
# Imagem ID: 25-34-2029-09275 calca alfaiataria bege curry
#  ---------------------
#
# Texto ID: 25-34-1714-09246
# Texto: calca amarracao crepe
# Maior Similaridade: 0.27115136
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1713-8259
# Texto: calca amarracao crepe
# Maior Similaridade: 0.27115136
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1655-09618
# Texto: calca ampla com pala listra
# Maior Similaridade: 0.27439356
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1936-0005
# Texto: calca ampla de algodao com liocel
# Maior Similaridade: 0.30140194
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2089-04331
# Texto: calca ampla listrada com barra italiana
# Maior Similaridade: 0.30497152
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1652-6048
# Texto: calca ampla marrom nozes
# Maior Similaridade: 0.26265442
# Imagem ID: 25-34-1440-09032 calca de couro classica botoes forrados
#  ---------------------
#
# Texto ID: 25-34-1937-09276
# Texto: calca basica de algodao texturizado
# Maior Similaridade: 0.31189936
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1595-09247
# Texto: calca cargo acetinada
# Maior Similaridade: 0.24062014
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1614-09538
# Texto: calca cargo cobra
# Maior Similaridade: 0.23579207
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1750-09259
# Texto: calca cargo de crepe rosa mosqueta
# Maior Similaridade: 0.2720958
# Imagem ID: 25-34-2006-09283 calca detalhe amarracao na barra rosa
#  ---------------------
#
# Texto ID: 25-34-1925-04331
# Texto: calca cargo de linho com tencel
# Maior Similaridade: 0.25294033
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1917-0005
# Texto: calca cenoura clochard com faixa de algodao preta
# Maior Similaridade: 0.28454944
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1726-6048
# Texto: calca cenoura de malha bam marrom com pregas na bainha
# Maior Similaridade: 0.2593525
# Imagem ID: 25-34-1611-09248 calca laranja aura ampla com botoes
#  ---------------------
#
# Texto ID: 25-34-1700-09246
# Texto: calca cenoura detalhe torcao na frente azul
# Maior Similaridade: 0.27117285
# Imagem ID: 25-34-1718-09634 calca de georgette pesado ampla estampada
#  ---------------------
#
# Texto ID: 25-34-1639-0030
# Texto: calca com cos duplo bege
# Maior Similaridade: 0.23086187
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1600-09247
# Texto: calca com cos transpassado bege gergelim
# Maior Similaridade: 0.24542502
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1644-09050
# Texto: calca com lapela barra
# Maior Similaridade: 0.23636048
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1615-0030
# Texto: calca com recorte lateral est onca
# Maior Similaridade: 0.26181966
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1604-1419
# Texto: calca com ziper frontal
# Maior Similaridade: 0.24450491
# Imagem ID: 52-13-5609-09283 top cropped de alcinha com pregas na frente e lastex nas costas rosa
#  ---------------------
#
# Texto ID: 25-34-1605-09612
# Texto: calca cos com lapelas listrada
# Maior Similaridade: 0.24020894
# Imagem ID: 25-05-4056-0105 bermuda jeans box com barra a fio
#  ---------------------
#
# Texto ID: 25-34-1642-09257
# Texto: calca cos elastico reta
# Maior Similaridade: 0.2582603
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1742-09205
# Texto: calca de alfaiataria em jeans
# Maior Similaridade: 0.3083216
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1202-0005
# Texto: calca de algodao basica preta
# Maior Similaridade: 0.28517234
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1608-04347
# Texto: calca de algodao cinza nimbus detalhe prega
# Maior Similaridade: 0.28305507
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1923-04526
# Texto: calca de algodao com recorte lateral
# Maior Similaridade: 0.3008577
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1638-09247
# Texto: calca de algodao contraforma bege com elastico cintura
# Maior Similaridade: 0.32164598
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1409-0278
# Texto: calca de algodao khaki
# Maior Similaridade: 0.2937464
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1117-0005
# Texto: calca de couro bolso lateral preto
# Maior Similaridade: 0.3125049
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-1725-04346
# Texto: calca de couro carrot franzido
# Maior Similaridade: 0.2779096
# Imagem ID: 25-34-1611-09248 calca laranja aura ampla com botoes
#  ---------------------
#
# Texto ID: 25-34-1443-09041
# Texto: calca de couro cintura alta passante diagonal
# Maior Similaridade: 0.29424378
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1721-0005
# Texto: calca de couro cintura alta pesponto
# Maior Similaridade: 0.28098243
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1575-0005
# Texto: calca de couro cintura marcada preto
# Maior Similaridade: 0.30930886
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-1440-09032
# Texto: calca de couro classica botoes forrados
# Maior Similaridade: 0.27926758
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1734-0005
# Texto: calca de couro com cinto barra botoes preto
# Maior Similaridade: 0.30551207
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-1442-09040
# Texto: calca de couro cos abaulado
# Maior Similaridade: 0.27029198
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1733-01011
# Texto: calca de couro cos elastico com stopper
# Maior Similaridade: 0.28411657
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1439-0005
# Texto: calca de couro cos pespontado
# Maior Similaridade: 0.25304097
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-2014-0005
# Texto: calca de couro cos rolote
# Maior Similaridade: 0.25890613
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-0839-0005
# Texto: calca de couro e malha cintura baixa
# Maior Similaridade: 0.2850111
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 25-34-0410-0005
# Texto: calca de couro e malha com pespontos
# Maior Similaridade: 0.26244798
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1724-09539
# Texto: calca de couro estampa cobra
# Maior Similaridade: 0.26843888
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1731-0402
# Texto: calca de couro mom recortes vinho
# Maior Similaridade: 0.2530342
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1918-6048
# Texto: calca de couro mom recortes
# Maior Similaridade: 0.25758937
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1101-09032
# Texto: calca de couro pantalona com fivelas no cos
# Maior Similaridade: 0.28614786
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-2135-04091
# Texto: calca de couro pantalona cos elastico color
# Maior Similaridade: 0.32180703
# Imagem ID: 25-34-1443-09041 calca de couro cintura alta passante diagonal
#  ---------------------
#
# Texto ID: 25-34-2015-0005
# Texto: calca de couro pantalona cos elastico
# Maior Similaridade: 0.3010381
# Imagem ID: 25-34-1409-0278 calca de algodao khaki
#  ---------------------
#
# Texto ID: 25-34-0926-0005
# Texto: calca de couro recortes cos elastico
# Maior Similaridade: 0.2916248
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1730-09050
# Texto: calca de couro recortes vermelho argila
# Maior Similaridade: 0.28783116
# Imagem ID: 07-20-6419-8259 vestido midi de seda com alca vermelho
#  ---------------------
#
# Texto ID: 25-34-0876-0005
# Texto: calca de couro reta preta com cos arredondado
# Maior Similaridade: 0.29538628
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-2016-09281
# Texto: calca de couro skinny basic
# Maior Similaridade: 0.27794194
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-0923-0005
# Texto: calca de couro stretch classica
# Maior Similaridade: 0.29616892
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1421-0023
# Texto: calca de couro stretch recortes
# Maior Similaridade: 0.28301823
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-04-0088-0005
# Texto: calca de couro stretch recortes
# Maior Similaridade: 0.28301823
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1723-09253
# Texto: calca de couro stretch recortes
# Maior Similaridade: 0.28301823
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1187-0005
# Texto: calca de crepe alfaiataria preta
# Maior Similaridade: 0.2730514
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1671-0005
# Texto: calca de crepe carrot preta
# Maior Similaridade: 0.26077718
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1670-09258
# Texto: calca de crepe carrot verde folha
# Maior Similaridade: 0.27608994
# Imagem ID: 25-34-1928-04113 calca de tricot maxi canelado
#  ---------------------
#
# Texto ID: 25-34-1766-0800
# Texto: calca de crepe com botoes na perna bege madeira
# Maior Similaridade: 0.28929555
# Imagem ID: 25-34-1440-09032 calca de couro classica botoes forrados
#  ---------------------
#
# Texto ID: 25-34-2023-0003
# Texto: calca de crepe off white
# Maior Similaridade: 0.28952038
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1509-0005
# Texto: calca de crepe preta com sobreposicao no cos e cinto forrado
# Maior Similaridade: 0.28277338
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-2039-0005
# Texto: calca de crepe preto
# Maior Similaridade: 0.2672302
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1746-09253
# Texto: calca de crepe verde encanto
# Maior Similaridade: 0.29322457
# Imagem ID: 25-34-1670-09258 calca de crepe carrot verde folha
#  ---------------------
#
# Texto ID: 25-34-1741-8259
# Texto: calca de crepe vermelho fiery
# Maior Similaridade: 0.27230242
# Imagem ID: 07-20-6419-8259 vestido midi de seda com alca vermelho
#  ---------------------
#
# Texto ID: 25-34-1967-09843
# Texto: calca de georgette com cos elastico estampado
# Maior Similaridade: 0.31025892
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1647-09657
# Texto: calca de georgette com pala de lastex estampado
# Maior Similaridade: 0.30044532
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2086-09817
# Texto: calca de georgette estampado
# Maior Similaridade: 0.27899963
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1678-09253
# Texto: calca de georgette pala larga verde bolso faca
# Maior Similaridade: 0.28847742
# Imagem ID: 25-34-1670-09258 calca de crepe carrot verde folha
#  ---------------------
#
# Texto ID: 25-34-1922-04504
# Texto: calca de georgette pantalona bege com detalhe a fio
# Maior Similaridade: 0.31053782
# Imagem ID: 25-34-1775-0109 calca jeans wide leg raw denim
#  ---------------------
#
# Texto ID: 25-34-1661-09258
# Texto: calca de georgette pantalona verde com detalhe a fio
# Maior Similaridade: 0.3393698
# Imagem ID: 25-34-1746-09253 calca de crepe verde encanto
#  ---------------------
#
# Texto ID: 25-34-1718-09634
# Texto: calca de georgette pesado ampla estampada
# Maior Similaridade: 0.30324504
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1720-0005
# Texto: calca de georgette pesado ampla preta cos com alfinete
# Maior Similaridade: 0.3283342
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1739-6262
# Texto: calca de georgette pesado pantalona amarela pala franzida
# Maior Similaridade: 0.31414935
# Imagem ID: 25-34-2029-09275 calca alfaiataria bege curry
#  ---------------------
#
# Texto ID: 25-34-1740-09548
# Texto: calca de georgette pesado pantalona pala franzida estampada
# Maior Similaridade: 0.28534335
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1738-09558
# Texto: calca de georgette pesado reta barra babados estampada
# Maior Similaridade: 0.29112172
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1901-09744
# Texto: calca de georgette pesado reta barra babados estampada
# Maior Similaridade: 0.29112172
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1660-09621
# Texto: calca de georgette reta com vivos estampado
# Maior Similaridade: 0.28759706
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1728-0005
# Texto: calca de jersey preta pantalona
# Maior Similaridade: 0.2777393
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1931-0005
# Texto: calca de linho cargo preta
# Maior Similaridade: 0.26661754
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1627-0003
# Texto: calca de linho off white
# Maior Similaridade: 0.2788539
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1751-09257
# Texto: calca de linho roxo fada
# Maior Similaridade: 0.26680923
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1607-0003
# Texto: calca de liocel off white perna reta
# Maior Similaridade: 0.29640025
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1727-0005
# Texto: calca de malha crepe com cos torcido
# Maior Similaridade: 0.26334348
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-2095-09831
# Texto: calca de malha lurex floral
# Maior Similaridade: 0.27928832
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1754-0005
# Texto: calca de malha preta com pala larga e fivela
# Maior Similaridade: 0.27501774
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1826-0030
# Texto: calca de sarja ampla recorte na lateral
# Maior Similaridade: 0.30496907
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1755-0005
# Texto: calca de sarja black loose com pespontos
# Maior Similaridade: 0.28625026
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-1821-0030
# Texto: calca de sarja boot 70 s
# Maior Similaridade: 0.26686132
# Imagem ID: 25-34-1440-09032 calca de couro classica botoes forrados
#  ---------------------
#
# Texto ID: 25-34-2067-01020
# Texto: calca de sarja caramelo com pence perna
# Maior Similaridade: 0.26850724
# Imagem ID: 25-34-1628-0800 calca uno bege madeira
#  ---------------------
#
# Texto ID: 25-34-1759-5459
# Texto: calca de sarja cinza gama com abotoamento frente
# Maior Similaridade: 0.30854088
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2061-0003
# Texto: calca de sarja com cos desfiado off white
# Maior Similaridade: 0.30399114
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1761-09541
# Texto: calca de sarja floral com pence joelho
# Maior Similaridade: 0.29336601
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1813-0030
# Texto: calca de sarja lateral deslocada
# Maior Similaridade: 0.2744665
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1757-0003
# Texto: calca de sarja off white bolso quadrado
# Maior Similaridade: 0.30526593
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-2069-0003
# Texto: calca de sarja off white com fivela lateral
# Maior Similaridade: 0.29924053
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1762-0003
# Texto: calca de sarja off white com recortes
# Maior Similaridade: 0.2981122
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1763-09259
# Texto: calca de sarja rosa mosqueta loose com botoes no cos
# Maior Similaridade: 0.28555003
# Imagem ID: 25-34-2006-09283 calca detalhe amarracao na barra rosa
#  ---------------------
#
# Texto ID: 25-34-1760-09252
# Texto: calca de sarja roxo mirtilo loose com botoes no cos
# Maior Similaridade: 0.2745147
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 25-34-2066-04526
# Texto: calca de sarja verde com fenda barra
# Maior Similaridade: 0.31660652
# Imagem ID: 25-34-1670-09258 calca de crepe carrot verde folha
#  ---------------------
#
# Texto ID: 25-34-1675-1974
# Texto: calca de tricot azul marinho com recorte
# Maior Similaridade: 0.30429524
# Imagem ID: 52-13-4927-09040 blusa de tricot com manga longa e decote redondo color lilas
#  ---------------------
#
# Texto ID: 25-34-1928-04113
# Texto: calca de tricot maxi canelado
# Maior Similaridade: 0.28912562
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2083-09281
# Texto: calca de tricot vazado marrom
# Maior Similaridade: 0.28760758
# Imagem ID: 52-13-5477-0005 blusa de malha listra metalic preta sem alca
#  ---------------------
#
# Texto ID: 25-34-1715-1974
# Texto: calca de tweed perna reta listra bicolor
# Maior Similaridade: 0.31266344
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1707-0005
# Texto: calca de twill basic preta
# Maior Similaridade: 0.2665269
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1201-09251
# Texto: calca de twill sarjado nude marzipan bolso quadrado
# Maior Similaridade: 0.2980412
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2006-09283
# Texto: calca detalhe amarracao na barra rosa
# Maior Similaridade: 0.29117587
# Imagem ID: 25-34-2006-09283 calca detalhe amarracao na barra rosa
#  ---------------------
#
# Texto ID: 25-34-1601-0024
# Texto: calca detalhe cos
# Maior Similaridade: 0.22997493
# Imagem ID: 52-13-5609-09283 top cropped de alcinha com pregas na frente e lastex nas costas rosa
#  ---------------------
#
# Texto ID: 25-34-1598-0003
# Texto: calca duo off white
# Maior Similaridade: 0.268373
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1599-0005
# Texto: calca duo preta
# Maior Similaridade: 0.24469815
# Imagem ID: 25-34-0923-0005 calca de couro stretch classica
#  ---------------------
#
# Texto ID: 25-34-2087-03023
# Texto: calca georgete bege kirli
# Maior Similaridade: 0.2423437
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 25-34-1719-04501
# Texto: calca jacquard cenoura azul bolso com pregas
# Maior Similaridade: 0.2946221
# Imagem ID: 25-34-1718-09634 calca de georgette pesado ampla estampada
#  ---------------------
#
# Texto ID: 25-34-1753-09252
# Texto: calca jacquard cenoura roxa com pregas
# Maior Similaridade: 0.26937062
# Imagem ID: 25-34-1644-09050 calca com lapela barra
#  ---------------------
#
# Texto ID: 25-34-2059-1530
# Texto: calca jeans bomber com elastico
# Maior Similaridade: 0.3050833
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1773-0101
# Texto: calca jeans boot 70 s com resina transparente
# Maior Similaridade: 0.3159765
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1777-0109
# Texto: calca jeans boot basic high dark blue
# Maior Similaridade: 0.3109557
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1799-0105
# Texto: calca jeans boot basic high fenda
# Maior Similaridade: 0.31060034
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1521-0101
# Texto: calca jeans boot basic midi fenda na bar
# Maior Similaridade: 0.292474
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1769-0105
# Texto: calca jeans boot vintage
# Maior Similaridade: 0.3081934
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-2092-1530
# Texto: calca jeans loose com recorte lateral
# Maior Similaridade: 0.3117853
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1798-0105
# Texto: calca jeans nipper basic
# Maior Similaridade: 0.2997772
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1781-0105
# Texto: calca jeans nipper stoned
# Maior Similaridade: 0.2993934
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1780-0105
# Texto: calca jeans pantalona barra a fio delave
# Maior Similaridade: 0.30247447
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1772-0109
# Texto: calca jeans pantalona rock botoes
# Maior Similaridade: 0.3026771
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1553-0105
# Texto: calca jeans skinny basic high blue medio
# Maior Similaridade: 0.31932086
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1778-0101
# Texto: calca jeans skinny basic high delave power
# Maior Similaridade: 0.31522468
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1919-0105
# Texto: calca jeans skinny basic high stoned
# Maior Similaridade: 0.31086388
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1779-0105
# Texto: calca jeans skinny basic midi delave power
# Maior Similaridade: 0.3062445
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1522-0105
# Texto: calca jeans skinny basic midi intense bl
# Maior Similaridade: 0.30666047
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1958-0105
# Texto: calca jeans straight stoned
# Maior Similaridade: 0.3033923
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1776-0105
# Texto: calca jeans straight
# Maior Similaridade: 0.30145764
# Imagem ID: 25-34-1781-0105 calca jeans nipper stoned
#  ---------------------
#
# Texto ID: 25-34-1775-0109
# Texto: calca jeans wide leg raw denim
# Maior Similaridade: 0.2999461
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1717-5471
# Texto: calca laise de algodao rose gold
# Maior Similaridade: 0.2722828
# Imagem ID: 25-34-1443-09041 calca de couro cintura alta passante diagonal
#  ---------------------
#
# Texto ID: 25-34-1611-09248
# Texto: calca laranja aura ampla com botoes
# Maior Similaridade: 0.30247936
# Imagem ID: 52-05-1594-09249 camisa de seda polo laranja manga longa
#  ---------------------
#
# Texto ID: 25-34-1208-09040
# Texto: calca mix la lilas nuvem
# Maior Similaridade: 0.23238963
# Imagem ID: 52-05-1563-09546 camisa de georgette pesado lenco manga ampla estampada
#  ---------------------
#
# Texto ID: 25-34-1448-0005
# Texto: calca pala virada preta
# Maior Similaridade: 0.24267185
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1658-09600
# Texto: calca pantalona com cos de elastico nas costas estampada
# Maior Similaridade: 0.27770287
# Imagem ID: 25-34-1655-09618 calca ampla com pala listra
#  ---------------------
#
# Texto ID: 25-34-1704-0003
# Texto: calca pantalona de linho detalhe cos pespontado off white
# Maior Similaridade: 0.29593801
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 25-34-1667-0005
# Texto: calca pantalona de tricot preta
# Maior Similaridade: 0.27934638
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1649-0005
# Texto: calca pantalona de tricot
# Maior Similaridade: 0.2705635
# Imagem ID: 25-34-1617-1974 calca reta marinho com cinto
#  ---------------------
#
# Texto ID: 25-34-1705-0005
# Texto: calca pantalona detalhe pregas preta
# Maior Similaridade: 0.26432413
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 25-34-1784-0005
# Texto: calca pantalona listra metalic com cos torcido
# Maior Similaridade: 0.281162
# Imagem ID: 25-05-4073-0105 bermuda jeans wide
#  ---------------------
#
# Texto ID: 25-34-1709-0005
# Texto: calca pantalona plissada com cos de elastico preta
# Maior Similaridade: 0.31609616
# Imagem ID: 25-34-1117-0005 calca de couro bolso lateral preto
#  ---------------------
#
# Texto ID: 25-34-1679-03023
# Texto: calca pantalona plissada
# Maior Similaridade: 0.28975165
# Imagem ID: 25-34-1409-0278 calca de algodao khaki
#  ---------------------
#
# Texto ID: 25-34-1650-0800
# Texto: calca reta bege madeira com bolso
# Maior Similaridade: 0.26217684
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1616-09557
# Texto: calca reta com bolso cargo lateral
# Maior Similaridade: 0.27977052
# Imagem ID: 25-34-1675-1974 calca de tricot azul marinho com recorte
#  ---------------------
#
# Texto ID: 25-34-1640-09607
# Texto: calca reta com elastico no cos estampada
# Maior Similaridade: 0.27516338
# Imagem ID: 52-13-5609-09283 top cropped de alcinha com pregas na frente e lastex nas costas rosa
#  ---------------------
#
# Texto ID: 25-34-1673-0024
# Texto: calca reta com fendas de crepe off white
# Maior Similaridade: 0.26841435
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1674-0024
# Texto: calca reta com recorte frontal
# Maior Similaridade: 0.23938844
# Imagem ID: 52-13-5609-09283 top cropped de alcinha com pregas na frente e lastex nas costas rosa
#  ---------------------
#
# Texto ID: 25-34-1633-6215
# Texto: calca reta de ggt com fendas laterais ma
# Maior Similaridade: 0.22793826
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 25-34-1656-8259
# Texto: calca reta de seda vermelho fiery
# Maior Similaridade: 0.29378366
# Imagem ID: 07-20-6419-8259 vestido midi de seda com alca vermelho
#  ---------------------
#
# Texto ID: 25-34-1651-09541
# Texto: calca reta floral cura aquarius com cos
# Maior Similaridade: 0.23997536
# Imagem ID: 07-20-6416-6048 vestido curto brocado mini flower
#  ---------------------
#
# Texto ID: 25-34-1618-09552
# Texto: calca reta listra bicolor
# Maior Similaridade: 0.28832585
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1617-1974
# Texto: calca reta marinho com cinto
# Maior Similaridade: 0.26267377
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-2013-0005
# Texto: calca reta piquet de algodao preta
# Maior Similaridade: 0.27827325
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1654-0005
# Texto: calca reta preta com pregas
# Maior Similaridade: 0.2676859
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 25-34-1573-0005
# Texto: calca sarja skinny basic high like leather
# Maior Similaridade: 0.2948737
# Imagem ID: 25-34-0926-0005 calca de couro recortes cos elastico
#  ---------------------
#
# Texto ID: 25-11-1175-0300
# Texto: calca slim em estampa cobra
# Maior Similaridade: 0.25716394
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-11-1174-09256
# Texto: calca uno amarelo narciso
# Maior Similaridade: 0.2583593
# Imagem ID: 25-34-2029-09275 calca alfaiataria bege curry
#  ---------------------
#
# Texto ID: 25-34-1628-0800
# Texto: calca uno bege madeira
# Maior Similaridade: 0.2340488
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 25-34-1687-0005
# Texto: legging textura
# Maior Similaridade: 0.2679715
# Imagem ID: 07-20-6669-0005 vestido de malha midi listra metalic com detalhe torcido
#  ---------------------
#
# Texto ID: 25-34-1645-0005
# Texto: legging tricot geo
# Maior Similaridade: 0.2764874
# Imagem ID: 52-06-0657-8259 t shirt de tricot bicolor listrada com lurex
#  ---------------------
#
# Texto ID: 52-05-1516-09557
# Texto: camisa alongada com botoes est onca
# Maior Similaridade: 0.27291572
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 52-05-1511-1419
# Texto: camisa alongada
# Maior Similaridade: 0.2834745
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-05-1566-0003
# Texto: camisa ampla de linho off white
# Maior Similaridade: 0.3099177
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1637-04331
# Texto: camisa azul sereia de linho
# Maior Similaridade: 0.2842265
# Imagem ID: 52-06-0642-09244 camiseta cropped
#  ---------------------
#
# Texto ID: 52-05-1538-0800
# Texto: camisa bege madeira com bolso frontal
# Maior Similaridade: 0.26820305
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 52-05-1560-0005
# Texto: camisa cropped de couro basica
# Maior Similaridade: 0.28974742
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 52-05-1541-09601
# Texto: camisa cropped polo ampla decote v estampada
# Maior Similaridade: 0.28125882
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 52-05-1556-0003
# Texto: camisa cropped polo ampla decote v off white
# Maior Similaridade: 0.31002754
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1625-09274
# Texto: camisa de algodao listrado azul maui
# Maior Similaridade: 0.30515906
# Imagem ID: 52-05-1637-04331 camisa azul sereia de linho
#  ---------------------
#
# Texto ID: 52-05-1561-0005
# Texto: camisa de couro elastico frontal barra
# Maior Similaridade: 0.2908914
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 52-05-1536-09563
# Texto: camisa de georgette com manga curta estampado
# Maior Similaridade: 0.3171179
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 52-05-1565-09544
# Texto: camisa de georgette leve polo manga curta estampada
# Maior Similaridade: 0.3130104
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-05-1563-09546
# Texto: camisa de georgette pesado lenco manga ampla estampada
# Maior Similaridade: 0.32395792
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-05-1455-0002
# Texto: camisa de manga presunto
# Maior Similaridade: 0.2843029
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1545-09251
# Texto: camisa de musseline
# Maior Similaridade: 0.27726066
# Imagem ID: 52-06-0639-09538 camiseta estampada cobra
#  ---------------------
#
# Texto ID: 52-05-1539-6048
# Texto: camisa de renda marrom nozes com recorte
# Maior Similaridade: 0.28668523
# Imagem ID: 52-06-0655-09253 t shirt de tricot verde basico com gola alta
#  ---------------------
#
# Texto ID: 52-05-1623-03045
# Texto: camisa de seda ampla lilas manga longa
# Maior Similaridade: 0.3152999
# Imagem ID: 52-06-0644-09257 camiseta slim
#  ---------------------
#
# Texto ID: 52-05-1568-0005
# Texto: camisa de seda ampla preta manga longa
# Maior Similaridade: 0.30253616
# Imagem ID: 52-13-4941-0005 blusa manga longa drapeada preta
#  ---------------------
#
# Texto ID: 52-05-1569-8259
# Texto: camisa de seda ampla vermelha manga longa
# Maior Similaridade: 0.29545087
# Imagem ID: 52-05-1569-8259 camisa de seda ampla vermelha manga longa
#  ---------------------
#
# Texto ID: 52-05-1604-09280
# Texto: camisa de seda basica laranja manga longa
# Maior Similaridade: 0.33180273
# Imagem ID: 52-13-5410-09248 polo tricot
#  ---------------------
#
# Texto ID: 52-05-1489-09040
# Texto: camisa de seda basica lilas
# Maior Similaridade: 0.29475006
# Imagem ID: 52-05-1565-09544 camisa de georgette leve polo manga curta estampada
#  ---------------------
#
# Texto ID: 52-05-1570-0003
# Texto: camisa de seda basica off white manga longa
# Maior Similaridade: 0.32076347
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-05-1571-5476
# Texto: camisa de seda basica verde manga longa
# Maior Similaridade: 0.31023782
# Imagem ID: 52-05-1571-5476 camisa de seda basica verde manga longa
#  ---------------------
#
# Texto ID: 52-05-1594-09249
# Texto: camisa de seda polo laranja manga longa
# Maior Similaridade: 0.3237835
# Imagem ID: 52-13-5410-09248 polo tricot
#  ---------------------
#
# Texto ID: 52-05-1564-04528
# Texto: camisa de seda polo rosa manga curta
# Maior Similaridade: 0.30352274
# Imagem ID: 52-05-1564-04528 camisa de seda polo rosa manga curta
#  ---------------------
#
# Texto ID: 52-05-1456-0201
# Texto: camisa de tricoline azul
# Maior Similaridade: 0.30240393
# Imagem ID: 52-05-1637-04331 camisa azul sereia de linho
#  ---------------------
#
# Texto ID: 52-05-1567-0200
# Texto: camisa de tricoline com recortes
# Maior Similaridade: 0.2981098
# Imagem ID: 52-05-1554-0200 camisa de tricoline listrada com babado
#  ---------------------
#
# Texto ID: 52-05-1586-0201
# Texto: camisa de tricoline essencial azul
# Maior Similaridade: 0.30857217
# Imagem ID: 52-06-0642-09244 camiseta cropped
#  ---------------------
#
# Texto ID: 52-05-1585-0002
# Texto: camisa de tricoline essencial branca
# Maior Similaridade: 0.3224723
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1554-0200
# Texto: camisa de tricoline listrada com babado
# Maior Similaridade: 0.28972763
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 03-06-0340-09254
# Texto: camisa de tricoline listrada verde cage
# Maior Similaridade: 0.30138874
# Imagem ID: 52-05-1550-03344 camisa over manga curta
#  ---------------------
#
# Texto ID: 52-05-1544-0002
# Texto: camisa de tricoline square branca
# Maior Similaridade: 0.3186052
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1575-0105
# Texto: camisa jeans basic manga curta
# Maior Similaridade: 0.29642802
# Imagem ID: 52-13-5352-0024 blusa com nervuras na manga
#  ---------------------
#
# Texto ID: 52-05-1517-1974
# Texto: camisa manga 7 8 marinho com martingale
# Maior Similaridade: 0.2908334
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1515-6262
# Texto: camisa manga longa de algodao com termocolante
# Maior Similaridade: 0.30790532
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-05-1426-0002
# Texto: camisa manga longa de algodao
# Maior Similaridade: 0.29549414
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-05-1629-0003
# Texto: camisa manga longa de sarja off white
# Maior Similaridade: 0.3165286
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1509-0024
# Texto: camisa match listras
# Maior Similaridade: 0.2700625
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1639-2030
# Texto: camisa natural de linho
# Maior Similaridade: 0.274776
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1628-0003
# Texto: camisa off white de linho
# Maior Similaridade: 0.30541378
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-05-1550-03344
# Texto: camisa over manga curta
# Maior Similaridade: 0.28485173
# Imagem ID: 52-05-1554-0200 camisa de tricoline listrada com babado
#  ---------------------
#
# Texto ID: 52-05-1642-04331
# Texto: camisa oversized com top listrada
# Maior Similaridade: 0.2805357
# Imagem ID: 52-06-0655-09253 t shirt de tricot verde basico com gola alta
#  ---------------------
#
# Texto ID: 52-05-1382-0003
# Texto: camisa richelieu etnico com manga curta
# Maior Similaridade: 0.28440595
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-06-0723-04331
# Texto: camiseta everyday slim
# Maior Similaridade: 0.27828848
# Imagem ID: 52-06-0641-0024 camiseta cropped
#  ---------------------
#
# Texto ID: 52-06-0724-0024
# Texto: camiseta everyday slim
# Maior Similaridade: 0.27828848
# Imagem ID: 52-06-0641-0024 camiseta cropped
#  ---------------------
#
# Texto ID: 52-06-0644-09257
# Texto: camiseta slim
# Maior Similaridade: 0.27235228
# Imagem ID: 52-06-0680-0003 t shirt de malha com manga curta
#  ---------------------
#
# Texto ID: 52-05-1396-0005
# Texto: tunica de couro oversized fraldada
# Maior Similaridade: 0.27772796
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5319-09738
# Texto: bata de georgette com decote v d babados estampado
# Maior Similaridade: 0.2550045
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5318-09656
# Texto: bata de georgette com manga curta estampado
# Maior Similaridade: 0.28822914
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5512-09628
# Texto: bata de georgette com manga curta estampado
# Maior Similaridade: 0.28822914
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5497-09744
# Texto: bata de georgette leve manga longa estampada
# Maior Similaridade: 0.30476218
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5429-09050
# Texto: bata de georgette leve manga longa frente frazida estampada
# Maior Similaridade: 0.30030486
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5421-0005
# Texto: bata de georgette preta com manga curta
# Maior Similaridade: 0.27823693
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 52-13-5534-04084
# Texto: bata manga curta azul grotto
# Maior Similaridade: 0.24898292
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 52-13-5368-0024
# Texto: blusa ampla de malha off white com manga
# Maior Similaridade: 0.32709727
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-13-5426-09633
# Texto: blusa basica de tule estampada com manga longa
# Maior Similaridade: 0.3264494
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5352-0024
# Texto: blusa com nervuras na manga
# Maior Similaridade: 0.27061957
# Imagem ID: 25-11-1272-0101 saia jeans box devale
#  ---------------------
#
# Texto ID: 52-13-5442-6048
# Texto: blusa cropped de malha crepe marrom ombro a ombro
# Maior Similaridade: 0.2971704
# Imagem ID: 52-13-5477-0005 blusa de malha listra metalic preta sem alca
#  ---------------------
#
# Texto ID: 52-13-5350-0005
# Texto: blusa de crepe com decote gota e manga
# Maior Similaridade: 0.3068489
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-13-5171-09041
# Texto: blusa de georgete sem alcas franzido
# Maior Similaridade: 0.29333982
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-13-5530-04504
# Texto: blusa de georgette bege com decote de babado
# Maior Similaridade: 0.29648697
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-13-5529-09738
# Texto: blusa de georgette com decote de babado estampado
# Maior Similaridade: 0.31686893
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-13-5396-09628
# Texto: blusa de georgette com torcao estampado
# Maior Similaridade: 0.31324106
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-13-5664-09819
# Texto: blusa de georgette estampado um ombro so
# Maior Similaridade: 0.29090387
# Imagem ID: 52-15-1373-01011 ragata de tricot amarelo um ombro com peplum
#  ---------------------
#
# Texto ID: 52-13-5370-09253
# Texto: blusa de georgette frente unica verde franjas
# Maior Similaridade: 0.32330436
# Imagem ID: 52-05-1550-03344 camisa over manga curta
#  ---------------------
#
# Texto ID: 52-13-5398-09249
# Texto: blusa de georgette laranja com torcao
# Maior Similaridade: 0.32207593
# Imagem ID: 52-05-1594-09249 camisa de seda polo laranja manga longa
#  ---------------------
#
# Texto ID: 52-13-5430-09556
# Texto: blusa de georgette leve frente unica amarracao estampado
# Maior Similaridade: 0.3186292
# Imagem ID: 52-05-1585-0002 camisa de tricoline essencial branca
#  ---------------------
#
# Texto ID: 52-13-5578-0003
# Texto: blusa de georgette leve um ombro so off white manga longa
# Maior Similaridade: 0.310084
# Imagem ID: 25-34-1608-04347 calca de algodao cinza nimbus detalhe prega
#  ---------------------
#
# Texto ID: 52-13-5371-09561
# Texto: blusa de georgette manga 7 8 babados estampado
# Maior Similaridade: 0.30465752
# Imagem ID: 52-05-1515-6262 camisa manga longa de algodao com termocolante
#  ---------------------
#
# Texto ID: 52-13-5501-04084
# Texto: blusa de georgette pesado manga longa azul decote costas
# Maior Similaridade: 0.3163782
# Imagem ID: 52-05-1637-04331 camisa azul sereia de linho
#  ---------------------
#
# Texto ID: 52-13-5433-09539
# Texto: blusa de georgette pesado manga longa estampada decote costas
# Maior Similaridade: 0.31367365
# Imagem ID: 52-05-1585-0002 camisa de tricoline essencial branca
#  ---------------------
#
# Texto ID: 52-13-5326-09563
# Texto: blusa de georgette um ombro estampado
# Maior Similaridade: 0.29795343
# Imagem ID: 52-15-1373-01011 ragata de tricot amarelo um ombro com peplum
#  ---------------------
#
# Texto ID: 52-13-5393-09258
# Texto: blusa de georgette verde com decote de babado
# Maior Similaridade: 0.31460184
# Imagem ID: 52-13-5409-03344 polo tricot
#  ---------------------
#
# Texto ID: 52-13-5394-09253
# Texto: blusa de georgette verde com tunel no decote
# Maior Similaridade: 0.30091566
# Imagem ID: 52-13-5409-03344 polo tricot
#  ---------------------
#
# Texto ID: 52-13-5420-09253
# Texto: blusa de jersey verde com detalhe torcido nas costas
# Maior Similaridade: 0.3203938
# Imagem ID: 52-13-5409-03344 polo tricot
#  ---------------------
#
# Texto ID: 52-06-0687-6048
# Texto: blusa de malha canelada marrom com manga media
# Maior Similaridade: 0.31044573
# Imagem ID: 52-05-1585-0002 camisa de tricoline essencial branca
#  ---------------------
#
# Texto ID: 52-13-5402-0003
# Texto: blusa de malha canelada off white com decote cruzado
# Maior Similaridade: 0.32558987
# Imagem ID: 52-05-1544-0002 camisa de tricoline square branca
#  ---------------------
#
# Texto ID: 52-06-0712-0024
# Texto: blusa de malha canelada preta com manga media
# Maior Similaridade: 0.31004983
# ...
# Texto: vestido de tricot vermelho com decote quadrado
# Maior Similaridade: 0.29945543
# Imagem ID: 52-15-1331-8259 ragata de tricot vermelha um ombro com peplum
#  ---------------------
#
# Texto ID: 07-20-6617-09550
# Texto: vestido de tule midi estampado com detalhe franzido
# Maior Similaridade: 0.29081956
# Imagem ID: 07-20-6385-01011 vestido longo amarelo papiro com abertur
#  ---------------------
#
# Texto ID: 07-20-6618-09634
# Texto: vestido de tule midi estampado com detalhe franzido
# Maior Similaridade: 0.29081956
# Imagem ID: 07-20-6385-01011 vestido longo amarelo papiro com abertur
#  ---------------------
#
# Texto ID: 07-20-6658-09566
# Texto: vestido de tule midi estampado com manga longa
# Maior Similaridade: 0.3088832
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6933-09905
# Texto: vestido de tule midi onca com detalhe lateral franzida
# Maior Similaridade: 0.30440837
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6500-09251
# Texto: vestido de twill midi corset nude
# Maior Similaridade: 0.29437113
# Imagem ID: 52-08-0790-0003 top faixa de renda flores intimates
#  ---------------------
#
# Texto ID: 07-20-6221-0005
# Texto: vestido drapeado curto preto manga longa
# Maior Similaridade: 0.30578637
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-7035-09819
# Texto: vestido georgette curto estampado
# Maior Similaridade: 0.30278295
# Imagem ID: 07-20-6385-01011 vestido longo amarelo papiro com abertur
#  ---------------------
#
# Texto ID: 07-20-6413-09542
# Texto: vestido gola alta manga longa floral
# Maior Similaridade: 0.28843665
# Imagem ID: 52-05-1563-09546 camisa de georgette pesado lenco manga ampla estampada
#  ---------------------
#
# Texto ID: 07-99-0036-09260
# Texto: vestido jacquard curto transpassado marrom manga longa com cinto
# Maior Similaridade: 0.3153036
# Imagem ID: 25-11-1108-0600 saia de couro cintura alta lapis
#  ---------------------
#
# Texto ID: 07-20-6728-0003
# Texto: vestido jacquard de algodao curto off white com decote coracao
# Maior Similaridade: 0.33040735
# Imagem ID: 25-34-1673-0024 calca reta com fendas de crepe off white
#  ---------------------
#
# Texto ID: 07-20-6065-0003
# Texto: vestido jacquard de algodao midi off white
# Maior Similaridade: 0.31782785
# Imagem ID: 25-34-1673-0024 calca reta com fendas de crepe off white
#  ---------------------
#
# Texto ID: 07-20-6582-09249
# Texto: vestido jacquard midi laranja ombro a ombro
# Maior Similaridade: 0.32124287
# Imagem ID: 52-13-5346-09249 regata de tricot laranja com gola alta basico
#  ---------------------
#
# Texto ID: 07-20-6572-09257
# Texto: vestido jersey roxo fada
# Maior Similaridade: 0.2886259
# Imagem ID: 07-20-6699-09744 vestido de georgette leve manga longa camada estampado
#  ---------------------
#
# Texto ID: 07-20-6571-09244
# Texto: vestido jersey tqc blue
# Maior Similaridade: 0.2736295
# Imagem ID: 52-13-5465-6215 blusa de malha marinho com decote v e manga longa raglan
#  ---------------------
#
# Texto ID: 07-20-6568-5471
# Texto: vestido laise de algodao midi rose gold
# Maior Similaridade: 0.30519417
# Imagem ID: 07-20-6608-6262 vestido de georgette pesado midi de alca babados amarelo com cinto
#  ---------------------
#
# Texto ID: 07-20-6752-0003
# Texto: vestido laura jacquard
# Maior Similaridade: 0.2738343
# Imagem ID: 07-20-6608-6262 vestido de georgette pesado midi de alca babados amarelo com cinto
#  ---------------------
#
# Texto ID: 07-20-6385-01011
# Texto: vestido longo amarelo papiro com abertur
# Maior Similaridade: 0.30177966
# Imagem ID: 07-20-6385-01011 vestido longo amarelo papiro com abertur
#  ---------------------
#
# Texto ID: 07-20-6495-09244
# Texto: vestido longo blue
# Maior Similaridade: 0.30310944
# Imagem ID: 07-20-6571-09244 vestido jersey tqc blue
#  ---------------------
#
# Texto ID: 07-20-6496-6262
# Texto: vestido longo bluse
# Maior Similaridade: 0.28205872
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6356-09557
# Texto: vestido longo com alca e fenda lateral
# Maior Similaridade: 0.2880305
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6382-09607
# Texto: vestido longo com amarracao no busto
# Maior Similaridade: 0.28192666
# Imagem ID: 25-11-1197-0005 saia transpassada bordado com micanga
#  ---------------------
#
# Texto ID: 07-20-6646-0005
# Texto: vestido longo com gola polo
# Maior Similaridade: 0.26817542
# Imagem ID: 25-11-1197-0005 saia transpassada bordado com micanga
#  ---------------------
#
# Texto ID: 07-20-6725-09253
# Texto: vestido longo com gola polo
# Maior Similaridade: 0.26817542
# Imagem ID: 25-11-1197-0005 saia transpassada bordado com micanga
#  ---------------------
#
# Texto ID: 07-20-7036-03023
# Texto: vestido longo de georgete bege kirli smp
# Maior Similaridade: 0.28072566
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6479-6262
# Texto: vestido longo de georgette um ombro so amarelo com fenda e franjas
# Maior Similaridade: 0.3111112
# Imagem ID: 07-20-6385-01011 vestido longo amarelo papiro com abertur
#  ---------------------
#
# Texto ID: 07-20-6447-09252
# Texto: vestido longo de jersey com recorte
# Maior Similaridade: 0.2878027
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6443-09249
# Texto: vestido longo de jersey um ombro so
# Maior Similaridade: 0.26730835
# Imagem ID: 52-10-5147-0005 top cropped com transpasse
#  ---------------------
#
# Texto ID: 07-20-6559-09050
# Texto: vestido longo de viscose maquinetada frente unica amarracao de corda vermelho
# Maior Similaridade: 0.30873415
# Imagem ID: 07-20-6419-8259 vestido midi de seda com alca vermelho
#  ---------------------
#
# Texto ID: 07-20-7013-09802
# Texto: vestido longo decote cruzado floral
# Maior Similaridade: 0.29613924
# Imagem ID: 07-20-6482-09544 vestido longo plissado frente unica estampado
#  ---------------------
#
# Texto ID: 07-20-6429-09654
# Texto: vestido longo decote franzido estampado
# Maior Similaridade: 0.2801259
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6360-09552
# Texto: vestido longo frente unica listra
# Maior Similaridade: 0.26697832
# Imagem ID: 07-20-6357-1974 vestido longo marinho assimetrico
#  ---------------------
#
# Texto ID: 07-20-6432-09660
# Texto: vestido longo manga longa decote ombro a ombro estampado onca
# Maior Similaridade: 0.29702795
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6357-1974
# Texto: vestido longo marinho assimetrico
# Maior Similaridade: 0.28084254
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6482-09544
# Texto: vestido longo plissado frente unica estampado
# Maior Similaridade: 0.28101546
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6786-0700
# Texto: vestido longo preto frente unica
# Maior Similaridade: 0.29621056
# Imagem ID: 07-20-6810-0005 vestido de seda midi preto borda festone
#  ---------------------
#
# Texto ID: 07-20-6345-09554
# Texto: vestido longo sem alca listrado
# Maior Similaridade: 0.26733372
# Imagem ID: 07-20-6447-09252 vestido longo de jersey com recorte
#  ---------------------
#
# Texto ID: 07-20-6782-04526
# Texto: vestido longo transpassado
# Maior Similaridade: 0.27943128
# Imagem ID: 07-20-6447-09252 vestido longo de jersey com recorte
#  ---------------------
#
# Texto ID: 07-20-6643-0024
# Texto: vestido match listras
# Maior Similaridade: 0.2618573
# Imagem ID: 07-20-6939-09280 vestido de malha crepe cut papaia
#  ---------------------
#
# Texto ID: 07-20-6161-0005
# Texto: vestido midi basic tricot preto
# Maior Similaridade: 0.3092368
# Imagem ID: 52-13-5281-0005 blusa de tricot preto com manga longa metalizado
#  ---------------------
#
# Texto ID: 07-20-6346-09638
# Texto: vestido midi com cinto jacquard
# Maior Similaridade: 0.26717642
# Imagem ID: 52-13-5285-0024 blusa manga longa com pala drapeada
#  ---------------------
#
# Texto ID: 07-20-6399-0030
# Texto: vestido midi com detalhe no busto bege g
# Maior Similaridade: 0.26263738
# Imagem ID: 25-34-1673-0024 calca reta com fendas de crepe off white
#  ---------------------
#
# Texto ID: 07-20-6380-09248
# Texto: vestido midi com manga sino laranja aura
# Maior Similaridade: 0.31068572
# Imagem ID: 52-05-1594-09249 camisa de seda polo laranja manga longa
#  ---------------------
#
# Texto ID: 07-20-5936-0005
# Texto: vestido midi crepe com cinto
# Maior Similaridade: 0.26478904
# Imagem ID: 07-20-6447-09252 vestido longo de jersey com recorte
#  ---------------------
#
# Texto ID: 07-20-6953-09279
# Texto: vestido midi crepe coral camelia
# Maior Similaridade: 0.298375
# Imagem ID: 07-20-6663-6048 vestido de renda ombro a ombro
#  ---------------------
#
# Texto ID: 07-20-6557-0003
# Texto: vestido midi de alca decote cruzado off white
# Maior Similaridade: 0.3025571
# Imagem ID: 25-34-1673-0024 calca reta com fendas de crepe off white
#  ---------------------
#
# Texto ID: 07-20-6538-2019
# Texto: vestido midi de alca decote reto acinturado e saia ampla com cinto laranja
# Maior Similaridade: 0.32978338
# Imagem ID: 07-20-6582-09249 vestido jacquard midi laranja ombro a ombro
#  ---------------------
#
# Texto ID: 07-20-6536-09246
# Texto: vestido midi de alcinha detalhe frente franzido azul
# Maior Similaridade: 0.30836442
# Imagem ID: 52-13-5424-04501 blusa jacquard manga longa azul frente torcida
#  ---------------------
#
# Texto ID: 07-20-6358-0024
# Texto: vestido midi de alcinha off white
# Maior Similaridade: 0.29970658
# Imagem ID: 25-34-1673-0024 calca reta com fendas de crepe off white
#  ---------------------
#
# Texto ID: 07-20-6597-09556
# Texto: vestido midi de georgette leve manga longa barra assimetrica estampado
# Maior Similaridade: 0.32188797
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6595-09546
# Texto: vestido midi de georgette pesado de alca decote costas estampado
# Maior Similaridade: 0.28976744
# Imagem ID: 07-99-0036-09260 vestido jacquard curto transpassado marrom manga longa com cinto
#  ---------------------
#
# Texto ID: 07-20-6604-09548
# Texto: vestido midi de georgette pesado manga ampla com recorte estampado
# Maior Similaridade: 0.32802024
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6444-09259
# Texto: vestido midi de jersey sem alca
# Maior Similaridade: 0.25995678
# Imagem ID: 25-05-4046-0005 bermuda de linho preta
#  ---------------------
#
# Texto ID: 07-20-6670-09248
# Texto: vestido midi de malha sem alca laranja
# Maior Similaridade: 0.2979928
# Imagem ID: 07-20-6592-09248 vestido de jersey curto com manga
#  ---------------------
#
# Texto ID: 07-20-6419-8259
# Texto: vestido midi de seda com alca vermelho
# Maior Similaridade: 0.30606055
# Imagem ID: 07-20-6632-8259 vestido de seda midi vermelho manga ampla
#  ---------------------
#
# Texto ID: 07-20-6467-1974
# Texto: vestido midi de tricot azul marinho
# Maior Similaridade: 0.30332977
# Imagem ID: 52-13-4927-09040 blusa de tricot com manga longa e decote redondo color lilas
#  ---------------------
#
# Texto ID: 07-20-6779-0005
# Texto: vestido midi de tricot com textura
# Maior Similaridade: 0.30617377
# Imagem ID: 52-06-0702-09565 t shirt de malha estampada com decote v
#  ---------------------
#
# Texto ID: 07-20-7011-5519
# Texto: vestido midi de tricot com textura
# Maior Similaridade: 0.30617377
# Imagem ID: 52-06-0702-09565 t shirt de malha estampada com decote v
#  ---------------------
#
# Texto ID: 07-20-6442-0005
# Texto: vestido midi de tricot sem mangas com re
# Maior Similaridade: 0.2818697
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6549-0003
# Texto: vestido midi decote reto franzido detalhe abertura lateral lastex nas costas off white
# Maior Similaridade: 0.3144058
# Imagem ID: 25-34-1627-0003 calca de linho off white
#  ---------------------
#
# Texto ID: 07-20-6033-0005
# Texto: vestido midi decote v manga longa e amarracao nas costas liso
# Maior Similaridade: 0.28894812
# Imagem ID: 25-34-1187-0005 calca de crepe alfaiataria preta
#  ---------------------
#
# Texto ID: 07-20-7022-09817
# Texto: vestido midi estampado com decote
# Maior Similaridade: 0.27254578
# Imagem ID: 07-20-6447-09252 vestido longo de jersey com recorte
#  ---------------------
#
# Texto ID: 07-20-6533-0003
# Texto: vestido midi lenco devore abstrato
# Maior Similaridade: 0.28727657
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 52-13-5351-0024
# Texto: vestido midi off white com recorte
# Maior Similaridade: 0.30680734
# Imagem ID: 25-34-1627-0003 calca de linho off white
#  ---------------------
#
# Texto ID: 07-20-6158-0005
# Texto: vestido midi sem manga tricot
# Maior Similaridade: 0.26648116
# Imagem ID: 52-10-5147-0005 top cropped com transpasse
#  ---------------------
#
# Texto ID: 07-20-6563-2030
# Texto: vestido midi textura chevron
# Maior Similaridade: 0.27684635
# Imagem ID: 07-20-6663-6048 vestido de renda ombro a ombro
#  ---------------------
#
# Texto ID: 07-20-6821-0300
# Texto: vestido midi verde bordado pedras
# Maior Similaridade: 0.29022652
# Imagem ID: 52-13-5433-09539 blusa de georgette pesado manga longa estampada decote costas
#  ---------------------
#
# Texto ID: 07-20-5963-0005
# Texto: vestido mini com alca de renda preto
# Maior Similaridade: 0.31898585
# Imagem ID: 07-20-6810-0005 vestido de seda midi preto borda festone
#  ---------------------
#
# Texto ID: 07-20-6441-09253
# Texto: vestido mini de jersey com decote organi
# Maior Similaridade: 0.29495904
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6575-09246
# Texto: vestido mini jersey tereza
# Maior Similaridade: 0.28743312
# Imagem ID: 25-11-1338-09277 short linho com bolsos
#  ---------------------
#
# Texto ID: 07-20-6379-04346
# Texto: vestido mini sem alca garden
# Maior Similaridade: 0.27551007
# Imagem ID: 07-20-6416-6048 vestido curto brocado mini flower
#  ---------------------
#
# Texto ID: 07-20-6348-09612
# Texto: vestido ombro a ombro listrado
# Maior Similaridade: 0.26393837
# Imagem ID: 52-06-0670-0024 regata alongada rib
#  ---------------------
#
# Texto ID: 07-20-6483-0005
# Texto: vestido ondas
# Maior Similaridade: 0.25079823
# Imagem ID: 25-34-1605-09612 calca cos com lapelas listrada
#  ---------------------
#
# Texto ID: 07-20-6352-0005
# Texto: vestido regata cut out
# Maior Similaridade: 0.25275663
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6351-0005
# Texto: vestido reto poa
# Maior Similaridade: 0.2592396
# Imagem ID: 07-20-6447-09252 vestido longo de jersey com recorte
#  ---------------------
#
# Texto ID: 07-20-6497-03023
# Texto: vestido t shirt longo
# Maior Similaridade: 0.2712669
# Imagem ID: 52-06-0723-04331 camiseta everyday slim
#  ---------------------
#
# Texto ID: 07-20-6414-09542
# Texto: vestido transpasse floral
# Maior Similaridade: 0.2862662
# Imagem ID: 07-20-6482-09544 vestido longo plissado frente unica estampado
#  ---------------------
#
# Texto ID: 07-20-6540-0005
# Texto: vestido tricot com top
# Maior Similaridade: 0.30055767
# Imagem ID: 52-13-4821-0005 blusa de tricot com textura preta manga longa
#  ---------------------
#
# Texto ID: 07-20-6403-0002
# Texto: vestido tricot decote quadrado listrado
# Maior Similaridade: 0.3011988
# Imagem ID: 52-06-0702-09565 t shirt de malha estampada com decote v
#  ---------------------
#
# Texto ID: 07-20-6778-0005
# Texto: vestido tricot transparencia
# Maior Similaridade: 0.29782826
# Imagem ID: 52-06-0702-09565 t shirt de malha estampada com decote v
#  ---------------------
#
# Texto ID: 07-20-6402-09248
# Texto: vestido tube
# Maior Similaridade: 0.2771167
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6401-0005
# Texto: vestido tube
# Maior Similaridade: 0.2771167
# Imagem ID: 25-34-1601-0024 calca detalhe cos
#  ---------------------
#
# Texto ID: 07-20-6659-09538
# Texto: vestido tule babados lili est leopardo
# Maior Similaridade: 0.3009041
# Imagem ID: 25-34-2095-09831 calca de malha lurex floral
#  ---------------------
#
# Texto ID: 07-20-5723-0005
# Texto: vestido um ombro sofia
# Maior Similaridade: 0.2597031
# Imagem ID: 52-10-5147-0005 top cropped com transpasse
#  ---------------------

# %%
# Função para plotar a imagem a partir do caminho
from matplotlib import pyplot as plt
from PIL import Image

def plot_image(image_path):
    image = Image.open(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
# Printando a similaridade de uma imagem com todos os textos
# Escolhendo uma imagem aleatória
img_idx = 1

print("Imagem ID:", df_img_embs.iloc[img_idx]["id_produto"], df.iloc[img_idx]['desc_produto'])

# Calculando a similaridade de cosseno entre a imagem escolhida e todos os textos
scores = cos_sim[:, img_idx]

# Plotando a imagem
image_path = df.iloc[img_idx]['file_path']
plot_image(image_path)

# Ordenando os índices dos textos pelo score em ordem decrescente
sorted_indices = np.argsort(scores)[::-1]

# Printando cada texto com a respectiva similaridade
for i in sorted_indices[:5]:
    text_id = df_text_embs.iloc[i]['id_produto']
    text_desc = df.iloc[i]['desc_produto']
    print("Texto ID:", text_id, "\nTexto:", text_desc)
    print("Similaridade:", scores[i])
    print(" --------------------- \n")
# Out:
# Imagem ID: 03-04-0478-6048 blazer alongado marrom nozes sem lapela
# Texto ID: 52-13-5460-09249
# Texto: blusa de malha laranja com decote v e manga longa raglan
# Similaridade: 0.30778202
#  ---------------------
#
# Texto ID: 07-20-6538-2019
# Texto: vestido midi de alca decote reto acinturado e saia ampla com cinto laranja
# Similaridade: 0.29767329
#  ---------------------
#
# Texto ID: 52-13-5430-09556
# Texto: blusa de georgette leve frente unica amarracao estampado
# Similaridade: 0.29292348
#  ---------------------
#
# Texto ID: 07-20-6604-09548
# Texto: vestido midi de georgette pesado manga ampla com recorte estampado
# Similaridade: 0.2893265
#  ---------------------
#
# Texto ID: 07-20-6472-09249
# Texto: vestido de georgette curto laranja decote drapeado
# Similaridade: 0.28613943
#  ---------------------

# %% [markdown]
# #### Parece que as descrições registradas não estão boas o suficiente.

# %% [markdown]
# ## Testando com descrições manuais

# %%
# Escolhendo uma imagem aleatória
img_idx = 621
image_path = df.iloc[img_idx]['file_path']
plot_image(image_path)

# Printando a descrição cadastrada da imagem
print("Imagem ID:", df_img_embs.iloc[img_idx]["id_produto"], df.iloc[img_idx]['desc_produto'])
# Out:
# Imagem ID: 07-20-6830-09283 vestido de georgette pesado longo rosa kimono

# %%
# Verificando qual é o texto mais similar a essa imagem
scores = cos_sim[:, img_idx]

max_text_idx = np.argmax(scores)
print("Imagem ID:", df_img_embs.iloc[img_idx]["id_produto"], df.iloc[img_idx]['desc_produto'])
print("Maior Similaridade:", scores[max_text_idx])
print("Texto ID:", df_text_embs.iloc[max_text_idx]["id_produto"], df.iloc[max_text_idx]['desc_produto'])
print(" --------------------- \n")
# Out:
# Imagem ID: 07-20-6830-09283 vestido de georgette pesado longo rosa kimono
# Maior Similaridade: 0.29705256
# Texto ID: 07-20-6475-09259 vestido de georgete midi rosa frente unica macrame
#  ---------------------

# %%
desc_manual_pt= "Vestido longo cor de rosa com mangas compridas e decote em V"
desc_manual = "Pink long dress with long sleeves and V-neck"

# embedding do texto
desc_manual_emb = text_model.encode(desc_manual)

# Calculando a similaridade de cosseno entre o texto manual e todas as imagens
cos_sim_manual = cosine_similarity([desc_manual_emb], img_embeddings)

scores = cos_sim_manual[0]  # Similaridades do texto manual com todas as imagens

# Mostrando a imagem com maior similaridade com o texto manual
max_img_idx = np.argmax(scores)
print("Texto Manual:", desc_manual)

# Mostrando a similaridade com a imagem com o id img_idx
score_img_idx = scores[img_idx]

print("Score da descrição manual com a imagem escolhida:", score_img_idx)

print("Maior Similaridade:", scores[max_img_idx])
print("Imagem ID:", df_img_embs.iloc[max_img_idx]["id_produto"], df.iloc[max_img_idx]['desc_produto'])
print(" --------------------- \n")

plot_image(df.iloc[max_img_idx]['file_path'])
# Out:
# Texto Manual: Pink long dress with long sleeves and V-neck
# Score da descrição manual com a imagem escolhida: 0.29016894
# Maior Similaridade: 0.31505886
# Imagem ID: 07-20-6786-0700 vestido longo preto frente unica
#  ---------------------

# %%
# Escolhendo uma imagem aleatória
img_idx = 333

image_path = df.iloc[img_idx]['file_path']
plot_image(image_path)

# %%
# Verificando qual é o texto mais similar a essa imagem
scores = cos_sim[:, img_idx]

max_text_idx = np.argmax(scores)
print("Imagem ID:", df_img_embs.iloc[img_idx]["id_produto"], df.iloc[img_idx]['desc_produto'])
print("Maior Similaridade:", scores[max_text_idx])
print("Texto ID:", df_text_embs.iloc[max_text_idx]["id_produto"], df.iloc[max_text_idx]['desc_produto'])
print(" --------------------- \n")
# Out:
# Imagem ID: 52-13-5559-0005 camiseta assimetrica
# Maior Similaridade: 0.328326
# Texto ID: 52-13-5009-0005 blusa de tricot com manga longa e decote redondo color preto
#  ---------------------

# %%
desc_manual = "Camiseta preta com uma manga só"

# embedding do texto
desc_manual_emb = text_model.encode(desc_manual)

# Calculando a similaridade de cosseno entre o texto manual e todas as imagens
cos_sim_manual = cosine_similarity([desc_manual_emb], img_embeddings)

scores = cos_sim_manual[0]  # Similaridades do texto manual com todas as imagens

# Mostrando a imagem com maior similaridade com o texto manual
max_img_idx = np.argmax(scores)
print("Texto Manual:", desc_manual)
print("Maior Similaridade:", scores[max_img_idx])
print("Imagem ID:", df_img_embs.iloc[max_img_idx]["id_produto"], df.iloc[max_img_idx]['desc_produto'])
print(" --------------------- \n")

plot_image(df.iloc[max_img_idx]['file_path'])
# Out:
# Texto Manual: Camiseta preta com uma manga só
# Maior Similaridade: 0.29433915
# Imagem ID: 52-13-5559-0005 camiseta assimetrica
#  ---------------------

# %% [markdown]
# ### Conclusões:
# O modelo consegue identificar características relevantes das imagens e textos, permitindo encontrar
# imagens similares a partir de descrições textuais, mas de forma muito generalizada. Para melhorar a
# precisão do modelo, seria necessário um fine-tuning com um dataset específico para o domínio de interesse.

# %%
df
# Out:
#                                                                                                            file_path  \
# 0                 animale_images_cropped/blazer/blazer_blazer-alfaiataria-est-onca-jacquard_bege_03-04-0464-0030.jpg
# 1      animale_images_cropped/blazer/blazer_blazer-alongado-marrom-nozes-sem-lapela_marrom-nozes_03-04-0478-6048.jpg
# 2                         animale_images_cropped/blazer/blazer_blazer-cinque-off-white_off-white_03-04-0460-0003.jpg
# 3                                 animale_images_cropped/blazer/blazer_blazer-cinque-preto_preto_03-04-0461-0005.jpg
# 4        animale_images_cropped/blazer/blazer_blazer-com-transpasse-de-crepe-off-white_off-white_03-04-0479-0024.jpg
# ..                                                                                                               ...
# 761                    animale_images_cropped/vestido/vestido_vestido-tricot-transparencia_preto_07-20-6778-0005.jpg
# 762                            animale_images_cropped/vestido/vestido_vestido-tube_laranja-aura_07-20-6402-09248.jpg
# 763                                    animale_images_cropped/vestido/vestido_vestido-tube_preto_07-20-6401-0005.jpg
# 764  animale_images_cropped/vestido/vestido_vestido-tule-babados-lili-est-leopardo_est-leopardo_07-20-6659-09538.jpg
# 765                          animale_images_cropped/vestido/vestido_vestido-um-ombro-sofia_preto_07-20-5723-0005.jpg
#
#            id_produto grupo_produto  \
# 0     03-04-0464-0030        blazer
# 1     03-04-0478-6048        blazer
# 2     03-04-0460-0003        blazer
# 3     03-04-0461-0005        blazer
# 4     03-04-0479-0024        blazer
# ..                ...           ...
# 761   07-20-6778-0005       vestido
# 762  07-20-6402-09248       vestido
# 763   07-20-6401-0005       vestido
# 764  07-20-6659-09538       vestido
# 765   07-20-5723-0005       vestido
#
#                                                                             file_name  \
# 0                blazer_blazer-alfaiataria-est-onca-jacquard_bege_03-04-0464-0030.jpg
# 1     blazer_blazer-alongado-marrom-nozes-sem-lapela_marrom-nozes_03-04-0478-6048.jpg
# 2                        blazer_blazer-cinque-off-white_off-white_03-04-0460-0003.jpg
# 3                                blazer_blazer-cinque-preto_preto_03-04-0461-0005.jpg
# 4       blazer_blazer-com-transpasse-de-crepe-off-white_off-white_03-04-0479-0024.jpg
# ..                                                                                ...
# 761                    vestido_vestido-tricot-transparencia_preto_07-20-6778-0005.jpg
# 762                            vestido_vestido-tube_laranja-aura_07-20-6402-09248.jpg
# 763                                    vestido_vestido-tube_preto_07-20-6401-0005.jpg
# 764  vestido_vestido-tule-babados-lili-est-leopardo_est-leopardo_07-20-6659-09538.jpg
# 765                          vestido_vestido-um-ombro-sofia_preto_07-20-5723-0005.jpg
#
#                                                                                                                                           link  \
# 0                https://animaleproductsimages.s3.us-east-1.amazonaws.com/blazer_blazer-alfaiataria-est-onca-jacquard_bege_03-04-0464-0030.jpg
# 1     https://animaleproductsimages.s3.us-east-1.amazonaws.com/blazer_blazer-alongado-marrom-nozes-sem-lapela_marrom-nozes_03-04-0478-6048.jpg
# 2                        https://animaleproductsimages.s3.us-east-1.amazonaws.com/blazer_blazer-cinque-off-white_off-white_03-04-0460-0003.jpg
# 3                                https://animaleproductsimages.s3.us-east-1.amazonaws.com/blazer_blazer-cinque-preto_preto_03-04-0461-0005.jpg
# 4       https://animaleproductsimages.s3.us-east-1.amazonaws.com/blazer_blazer-com-transpasse-de-crepe-off-white_off-white_03-04-0479-0024.jpg
# ..                                                                                                                                         ...
# 761                    https://animaleproductsimages.s3.us-east-1.amazonaws.com/vestido_vestido-tricot-transparencia_preto_07-20-6778-0005.jpg
# 762                            https://animaleproductsimages.s3.us-east-1.amazonaws.com/vestido_vestido-tube_laranja-aura_07-20-6402-09248.jpg
# 763                                    https://animaleproductsimages.s3.us-east-1.amazonaws.com/vestido_vestido-tube_preto_07-20-6401-0005.jpg
# 764  https://animaleproductsimages.s3.us-east-1.amazonaws.com/vestido_vestido-tule-babados-lili-est-leopardo_est-leopardo_07-20-6659-09538.jpg
# 765                          https://animaleproductsimages.s3.us-east-1.amazonaws.com/vestido_vestido-um-ombro-sofia_preto_07-20-5723-0005.jpg
#
#              PRODUTOS  \
# 0     03-04-0464-0030
# 1     03-04-0478-6048
# 2     03-04-0460-0003
# 3     03-04-0461-0005
# 4     03-04-0479-0024
# ..                ...
# 761   07-20-6778-0005
# 762  07-20-6402-09248
# 763   07-20-6401-0005
# 764  07-20-6659-09538
# 765   07-20-5723-0005
#
#                                                                                                                                                                                                                                                                                          CARACTERISTICAS  \
# 0                                                                                       {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRIMENTO_MANGA: COMPRIDA;TIPO_MANGA: REGULAR;COR_PREDOMINANTE: BEGE;LOCALIZACAO_ESTAMPA: ROUPA_INTEIRA;ZOOM_ESTAMPA: MEDIO;ESTAMPA: ANIMALPRINT_ONCA;ESTILO: CASUAL;}
# 1                                                                                                        {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRIMENTO_MANGA: COMPRIDA;TIPO_MANGA: REGULAR;COR_PREDOMINANTE: BEGE;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: SOCIAL;}
# 2                                                                                                      {COMPRIMENTO: MEDIO;MODELAGEM: AJUSTADA;COMPRIMENTO_MANGA: COMPRIDA;TIPO_MANGA: REGULAR;COR_PREDOMINANTE: BRANCO;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: SOCIAL;}
# 3                                                                                               {COMPRIMENTO: MEDIO; MODELAGEM: AJUSTADA; COMPRIMENTO_MANGA: COMPRIDA; TIPO_MANGA: REGULAR; COR_PREDOMINANTE: PRETO; LOCALIZACAO_ESTAMPA: N/A; ZOOM_ESTAMPA: N/A; ESTAMPA: SEM_ESTAMPA; ESTILO: SOCIAL;}
# 4                                                                                              {COMPRIMENTO: MEDIO; MODELAGEM: AJUSTADA; COMPRIMENTO_MANGA: COMPRIDA; TIPO_MANGA: REGULAR; COR_PREDOMINANTE: BRANCO; LOCALIZACAO_ESTAMPA: N/A; ZOOM_ESTAMPA: N/A; ESTAMPA: SEM_ESTAMPA; ESTILO: SOCIAL;}
# ..                                                                                                                                                                                                                                                                                                   ...
# 761                                    {COMPRIMENTO_SAIA: CALCANHAR;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: N/A;MODELAGEM_SAIA: REGULAR;FENDA_PERNA: SIM;DECOTE_OU_GOLA: HALTER;AMARRACAO: N/A;COR_PREDOMINANTE: PRETO;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: CASUAL;}
# 762                                 {COMPRIMENTO_SAIA: CALCANHAR;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: N/A;MODELAGEM_SAIA: REGULAR;FENDA_PERNA: N/A;DECOTE_OU_GOLA: REDONDA;AMARRACAO: N/A;COR_PREDOMINANTE: LARANJA;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: BASICO;}
# 763                                   {COMPRIMENTO_SAIA: CALCANHAR;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: N/A;MODELAGEM_SAIA: REGULAR;FENDA_PERNA: N/A;DECOTE_OU_GOLA: REDONDA;AMARRACAO: N/A;COR_PREDOMINANTE: PRETO;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: SOCIAL;}
# 764  {COMPRIMENTO_SAIA: CALCANHAR;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: OMBRO_A_OMBRO;MODELAGEM_SAIA: EVASÊ;FENDA_PERNA: N/A;DECOTE_OU_GOLA: TOMARA_QUE_CAIA;AMARRACAO: N/A;COR_PREDOMINANTE: BEGE;LOCALIZACAO_ESTAMPA: ROUPA_INTEIRA;ZOOM_ESTAMPA: MEDIO;ESTAMPA: ANIMALPRINT_ONCA;ESTILO: FESTIVO;}
# 765                               {COMPRIMENTO_SAIA: MINI;COMPRIMENTO_MANGA: SEM_MANGA;TIPO_MANGA: OMBRO_UNICO;MODELAGEM_SAIA: ASSIMETRICA;FENDA_PERNA: N/A;DECOTE_OU_GOLA: N/A;AMARRACAO: N/A;COR_PREDOMINANTE: PRETO;LOCALIZACAO_ESTAMPA: N/A;ZOOM_ESTAMPA: N/A;ESTAMPA: SEM_ESTAMPA;ESTILO: FESTIVO;}
#
#     LOCALIZACAO_ESTAMPA COR_PREDOMINANTE   DECOTE_OU_GOLA  ...   ESTILO  \
# 0         ROUPA_INTEIRA             BEGE             None  ...   CASUAL
# 1                   N/A             BEGE             None  ...   SOCIAL
# 2                   N/A           BRANCO             None  ...   SOCIAL
# 3                   N/A            PRETO             None  ...   SOCIAL
# 4                   N/A           BRANCO             None  ...   SOCIAL
# ..                  ...              ...              ...  ...      ...
# 761                 N/A            PRETO           HALTER  ...   CASUAL
# 762                 N/A          LARANJA          REDONDA  ...   BASICO
# 763                 N/A            PRETO          REDONDA  ...   SOCIAL
# 764       ROUPA_INTEIRA             BEGE  TOMARA_QUE_CAIA  ...  FESTIVO
# 765                 N/A            PRETO              N/A  ...  FESTIVO
#
#         TIPO_MANGA TIPO_CINTURA COMPRIMENTO MODELAGEM           ESTAMPA  \
# 0          REGULAR         None       MEDIO  AJUSTADA  ANIMALPRINT_ONCA
# 1          REGULAR         None       MEDIO  AJUSTADA       SEM_ESTAMPA
# 2          REGULAR         None       MEDIO  AJUSTADA       SEM_ESTAMPA
# 3          REGULAR         None       MEDIO  AJUSTADA       SEM_ESTAMPA
# 4          REGULAR         None       MEDIO  AJUSTADA       SEM_ESTAMPA
# ..             ...          ...         ...       ...               ...
# 761            N/A         None        None      None       SEM_ESTAMPA
# 762            N/A         None        None      None       SEM_ESTAMPA
# 763            N/A         None        None      None       SEM_ESTAMPA
# 764  OMBRO_A_OMBRO         None        None      None  ANIMALPRINT_ONCA
# 765    OMBRO_UNICO         None        None      None       SEM_ESTAMPA
#
#     FENDA_PERNA MODELAGEM_SAIA TIPO_BARRA  \
# 0          None           None       None
# 1          None           None       None
# 2          None           None       None
# 3          None           None       None
# 4          None           None       None
# ..          ...            ...        ...
# 761         SIM        REGULAR       None
# 762         N/A        REGULAR       None
# 763         N/A        REGULAR       None
# 764         N/A          EVASÊ       None
# 765         N/A    ASSIMETRICA       None
#
#                                  desc_produto
# 0        blazer alfaiataria est onca jacquard
# 1     blazer alongado marrom nozes sem lapela
# 2                     blazer cinque off white
# 3                         blazer cinque preto
# 4    blazer com transpasse de crepe off white
# ..                                        ...
# 761              vestido tricot transparencia
# 762                              vestido tube
# 763                              vestido tube
# 764    vestido tule babados lili est leopardo
# 765                    vestido um ombro sofia
#
# [766 rows x 24 columns]

# %%
# Salvando df em parquet
df.to_parquet("datasets/base.parquet")
